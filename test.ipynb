# %%
import Beta

res = Beta.get_data()

# %%
print(res)
# Out:
# {'year': 2023, '국어':      표준점수   남자   여자
# 0     150   34   30
# 1     148   24   35
# 2     147   98   63
# 3     146   65   83
# 4     145  160  117
# ..    ...  ...  ...
# 106    43   25   16
# 107    42    2    1
# 108    41   80   27
# 109    40    4    3
# 110    39  145   74
#
# [111 rows x 3 columns], '수학':      표준점수    남자    여자
# 111   148   516    96
# 112   146    75    11
# 113   145   412   105
# 114   144   642   158
# 115   143    13     3
# ..    ...   ...   ...
# 192    66  1249  1418
# 193    65   273   283
# 194    64   485   491
# 195    63    89   134
# 196    62   242   181
#
# [86 rows x 3 columns], '생활과 윤리':      표준점수    남자    여자
# 197    65  2034  4323
# 198    63  3561  7526
# 199    62   500  1044
# 200    61  2237  4728
# 201    60  1435  2796
# 202    59  1101  2179
# 203    58  3022  5603
# 204    57  1573  2817
# 205    56  1453  2631
# 206    55  1006  1671
# 207    54  1491  2623
# 208    53  2218  3812
# 209    52  1330  2269
# 210    51   978  1649
# ...
