# %%
import os
import sys

# 현재 파일이 위치한 디렉토리 기준으로 경로 추가
current_dir = os.path.dirname(os.path.abspath('test.ipynb'))
sys.path.append(current_dir)

# %%
import Beta

data = Beta.get_data()

# %%
data.keys()
# Out:
# dict_keys([2021, 2022, 2023, 2024])

# %%
data[2021].keys()
# Out:
# dict_keys(['국어', '수학 가형', '수학 나형', '생활과 윤리', '윤리와 사상', '한국지리', '세계지리', '동아시아사', '세계사', '경제', '정치와 법', '사회·문화', '물리학 I', '화학 I', '생명과학 I', '지구과학 I', '물리학 II', '화학 II', '생명과학 II', '지구과학 II', '농업 이해', '농업 기초 기술', '공업 일반', '기초 제도', '상업 경제', '회계 원리', '해양의 이해', '수산·해운 산업 기초', '인간 발달', '생활 서비스 산업의 이해', '독일어 I', '프랑스어 I', '스페인어 I', '중국어 I', '일본어 I', '러시아어 I', '아랍어 I', '베트남어 I', '한문 I'])

# %%
data[2021].values()
# Out:
# dict_values([    표준점수   남자   여자
# 0    144   93   58
# 1    142  256  181
# 2    141  161  147
# 3    140  395  242
# 4    139  583  422
# ..   ...  ...  ...
# 94    42   12    8
# 95    41   11   10
# 96    40    5    6
# 97    39   13   10
# 98    36  135   58
#
# [99 rows x 3 columns],      표준점수    남자   여자
# 99    137   790  181
# 100   135    16    8
# 101   134   124   35
# 102   133  1476  435
# 103   132     5    0
# ..    ...   ...  ...
# 180    55   268  151
# 181    54    59   33
# 182    53    77   27
# 183    52    45    9
# 184    50   105   33
#
# [86 rows x 3 columns],      표준점수    남자    여자
# 185   137   929   498
# 186   135    25    27
# 187   134  1930  1448
# 188   133    21    15
# 189   132   123    88
# ..    ...   ...   ...
# 253    68   407   543
# 254    67   404   481
# 255    66   130   156
# 256    65    90   118
# 257    64   166   129
#
# [73 rows x 3 columns],      표준점수    남자    여자
# 258    65  1948  3496
# 259    64  2089  4140
# 260    63  1635  2832
# ...
